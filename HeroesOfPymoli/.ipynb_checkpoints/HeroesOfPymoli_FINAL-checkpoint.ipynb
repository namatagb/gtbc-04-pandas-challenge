# %%
# Dependencies and Setup
import pandas as pd
import numpy as np

# File to Load (Remember to Change These)
file_to_load = "Resources/purchase_data.csv"

# Read Purchasing File and store into Pandas data frame
purchase_data = pd.read_csv(file_to_load)
purchase_data
# Out:
#      Purchase ID             SN  Age  Gender  Item ID  \
# 0              0        Lisim78   20    Male      108
# 1              1    Lisovynya38   40    Male      143
# 2              2     Ithergue48   24    Male       92
# 3              3  Chamassasya86   24    Male      100
# 4              4      Iskosia90   23    Male      131
# ..           ...            ...  ...     ...      ...
# 775          775     Aethedru70   21  Female       60
# 776          776         Iral74   21    Male      164
# 777          777     Yathecal72   20    Male       67
# 778          778        Sisur91    7    Male       92
# 779          779      Ennrian78   24    Male       50
#
#                                      Item Name  Price
# 0    Extraction, Quickblade Of Trembling Hands   3.53
# 1                            Frenzied Scimitar   1.56
# 2                                 Final Critic   4.88
# 3                                  Blindscythe   3.27
# 4                                         Fury   1.44
# ..                                         ...    ...
# 775                                       Wolf   3.54
# 776                           Exiled Doomblade   1.63
# 777      Celeste, Incarnation of the Corrupted   3.46
# 778                               Final Critic   4.19
# 779                                       Dawn   4.60
#
# [780 rows x 7 columns]

# %%
total_players_count = len(purchase_data["SN"].value_counts())
total_players_df = pd.DataFrame({
    "Total Players": [total_players_count]
})

total_players_df
# Out:
#    Total Players
# 0            576

# %%
purchasing_analysis_df = pd.DataFrame({
    "Number of Unique Items":[len(purchase_data["Item ID"].value_counts())],
    "Average Price": [purchase_data["Price"].mean()], 
    "Number of Purchases": [purchase_data["Purchase ID"].count()],
    "Total Revenue": [purchase_data["Price"].sum()]
    
})
purchasing_analysis_df["Average Price"] = purchasing_analysis_df["Average Price"].map("${:.2f}".format)
purchasing_analysis_df["Total Revenue"] = purchasing_analysis_df["Total Revenue"].map("${:.2f}".format)
purchasing_analysis_df.round(2)
# Out:
#    Number of Unique Items Average Price  Number of Purchases Total Revenue
# 0                     179         $3.05                  780      $2379.77

# %%
gender_dem_df = pd.DataFrame()

gender_dem_df["Total Players"] = purchase_data.groupby(["Gender"])["SN"].nunique()
gender_dem_df["Percentage of Players"] = (purchase_data.groupby(["Gender"])["SN"].nunique()/
                                           purchase_data.groupby(["Gender"])["SN"].nunique().sum())*100

gender_dem_df["Percentage of Players"] = gender_dem_df["Percentage of Players"].map("{:.2f}%".format)
gender_dem_df.sort_values(by=["Total Players"], ascending=False)
# Out:
#                        Total Players Percentage of Players
# Gender
# Male                             484                84.03%
# Female                            81                14.06%
# Other / Non-Disclosed             11                 1.91%

# %%
gender_dem_df = purchase_data.groupby(["Gender"])

total_players_gen = gender_dem_df["SN"].nunique()

perc_players_gen = (purchase_data.groupby(["Gender"])["SN"].nunique()/
                                           purchase_data.groupby(["Gender"])["SN"].nunique().sum())*100

gender_dem_df = pd.DataFrame({
    "Total Players": total_players_gen,
    "Percentage of Players": perc_players_gen.map("{:.2f}%".format)
})

gender_dem_df
# Out:
#                        Total Players Percentage of Players
# Gender
# Female                            81                14.06%
# Male                             484                84.03%
# Other / Non-Disclosed             11                 1.91%

# %%
#create data frame to store gender
purchasing_gen_df = pd.DataFrame()

#calculate total players for each gender
total_players_gen_1 = purchase_data["Gender"].value_counts()
purchasing_gen_df["Total Players"] = total_players_gen

avg_purchase =  purchase_data.groupby(["Gender"])["Price"].mean().round(2).map("${:.2f}".format)
purchasing_gen_df["Average Purchase Price"] = avg_purchase

total_purchase = purchase_data.groupby(["Gender"])["Price"].sum().round(2).map("${:.2f}".format)
purchasing_gen_df["Total Purchase Value"] = total_purchase

per_person = purchase_data.groupby(["Gender"])["Price"].sum()/total_players_gen
purchasing_gen_df["Avg Total Purchase per Person"] = per_person.round(2).map("${:.2f}".format)

purchasing_gen_df.head()
# Out:
#                        Total Players Average Purchase Price  \
# Gender
# Female                            81                  $3.20
# Male                             484                  $3.02
# Other / Non-Disclosed             11                  $3.35
#
#                       Total Purchase Value Avg Total Purchase per Person
# Gender
# Female                             $361.94                         $4.47
# Male                              $1967.64                         $4.07
# Other / Non-Disclosed               $50.19                         $4.56

# %%
print(purchase_data['Age'].max())
print(purchase_data['Age'].min())

bins = [0, 9.9, 14.9, 19.9, 24.9, 29.9, 34.9, 39.9, 49.9]
age_range = ["10", "10-14", "15-19", "20-24", "25-29", "30-34", "35-39", "40+"]

purchase_data["Age Range"] = pd.cut(purchase_data["Age"], bins, labels=age_range)

age_group = purchase_data.groupby("Age Range")

count_age_group = age_group["SN"].nunique()

perc_age_group = (count_age_group/total_players_count)*100

age_dem_df = pd.DataFrame({
    "Total Players" : count_age_group,
    "Percentage of Players": perc_age_group.map("{:.2f}%".format)
})

age_dem_df.index.name = None
age_dem_df
# Out:
# 45
# 7
#        Total Players Percentage of Players
# 10                17                 2.95%
# 10-14             22                 3.82%
# 15-19            107                18.58%
# 20-24            258                44.79%
# 25-29             77                13.37%
# 30-34             52                 9.03%
# 35-39             31                 5.38%
# 40+               12                 2.08%

# %%
bins = [0, 9.9, 14.9, 19.9, 24.9, 29.9, 34.9, 39.9, 49.9]
age_range = ["10", "10-14", "15-19", "20-24", "25-29", "30-34", "35-39", "40+"]

purchase_data["Age Range"] = pd.cut(purchase_data["Age"], bins, labels=age_range)

age_group = purchase_data.groupby("Age Range")

purchase_count_age = age_group["Purchase ID"].nunique()

purchase_avg_age = age_group["Price"].mean()

purchase_total_age = age_group["Price"].sum()

purchase_avg_per_age = (purchase_total_age / count_age_group)

purchase_analysis = pd.DataFrame({
    "Purchase Count": purchase_count_age,
    "Average Purchase Price": purchase_avg_age.round(2).map("${:.2f}".format),
    "Total Purchase Value": purchase_total_age.round(2).map("${:.2f}".format),
    "Avg Total Purchase per Person": purchase_avg_per_age.round(2).map("${:.2f}".format)
})

purchase_analysis
# Out:
#            Purchase Count Average Purchase Price Total Purchase Value  \
# Age Range
# 10                     23                  $3.35               $77.13
# 10-14                  28                  $2.96               $82.78
# 15-19                 136                  $3.04              $412.89
# 20-24                 365                  $3.05             $1114.06
# 25-29                 101                  $2.90              $293.00
# 30-34                  73                  $2.93              $214.00
# 35-39                  41                  $3.60              $147.67
# 40+                    13                  $2.94               $38.24
#
#           Avg Total Purchase per Person
# Age Range
# 10                                $4.54
# 10-14                             $3.76
# 15-19                             $3.86
# 20-24                             $4.32
# 25-29                             $3.81
# 30-34                             $4.12
# 35-39                             $4.76
# 40+                               $3.19

# %%
purchasers = purchase_data.groupby("SN")

purchasers_count = purchasers["Purchase ID"].count()

avg_purchasers = purchasers["Price"].mean()

total_purchasers = purchasers["Price"].sum()

top_spenders = pd.DataFrame({
    "Purchase Count": purchasers_count,
    "Average Purchase Price": avg_purchasers.round(2).map("${:.2f}".format),
    "Total Purchase Price": total_purchasers.round(2).map("${:.2f}".format)
    
})

top_spenders.sort_values(["Purchase Count"],ascending=False).head()
# Out:
#              Purchase Count Average Purchase Price Total Purchase Price
# SN
# Lisosia93                 5                  $3.79               $18.96
# Iral74                    4                  $3.40               $13.62
# Idastidru52               4                  $3.86               $15.45
# Asur53                    3                  $2.48                $7.44
# Inguron55                 3                  $3.70               $11.11

# %%
most_popular_items = purchase_data[["Item ID","Item Name","Price"]]

items_grouped = most_popular_items.groupby(["Item ID", "Item Name"])

count_popular_items = items_grouped["Price"].count()
                                    
popular_items_sum = (items_grouped["Price"].sum())
                                    
popular_items_cost = popular_items_sum/count_popular_items
                                    
most_popular_items_df = pd.DataFrame({
    "Purchase Count": count_popular_items,
    "Item Price": popular_items_cost,
    "Total Purchase Value": popular_items_sum
})


sorted_popular = most_popular_items_df.sort_values(by='Purchase Count', ascending=False).head()


sorted_popular.style.format({
    "Item Price": "${:.2f}",
    "Total Purchase Value": "${:.2f}"
})
# Out:
# <style  type="text/css" >
# </style><table id="T_74359_" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Purchase Count</th>        <th class="col_heading level0 col1" >Item Price</th>        <th class="col_heading level0 col2" >Total Purchase Value</th>    </tr>    <tr>        <th class="index_name level0" >Item ID</th>        <th class="index_name level1" >Item Name</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_74359_level0_row0" class="row_heading level0 row0" >92</th>
#                         <th id="T_74359_level1_row0" class="row_heading level1 row0" >Final Critic</th>
#                         <td id="T_74359_row0_col0" class="data row0 col0" >13</td>
#                         <td id="T_74359_row0_col1" class="data row0 col1" >$4.61</td>
#                         <td id="T_74359_row0_col2" class="data row0 col2" >$59.99</td>
#             </tr>
#             <tr>
#                         <th id="T_74359_level0_row1" class="row_heading level0 row1" >178</th>
#                         <th id="T_74359_level1_row1" class="row_heading level1 row1" >Oathbreaker, Last Hope of the Breaking Storm</th>
#                         <td id="T_74359_row1_col0" class="data row1 col0" >12</td>
#                         <td id="T_74359_row1_col1" class="data row1 col1" >$4.23</td>
#                         <td id="T_74359_row1_col2" class="data row1 col2" >$50.76</td>
#             </tr>
#             <tr>
#                         <th id="T_74359_level0_row2" class="row_heading level0 row2" >145</th>
#                         <th id="T_74359_level1_row2" class="row_heading level1 row2" >Fiery Glass Crusader</th>
#                         <td id="T_74359_row2_col0" class="data row2 col0" >9</td>
#                         <td id="T_74359_row2_col1" class="data row2 col1" >$4.58</td>
#                         <td id="T_74359_row2_col2" class="data row2 col2" >$41.22</td>
#             </tr>
#             <tr>
#                         <th id="T_74359_level0_row3" class="row_heading level0 row3" >132</th>
#                         <th id="T_74359_level1_row3" class="row_heading level1 row3" >Persuasion</th>
#                         <td id="T_74359_row3_col0" class="data row3 col0" >9</td>
#                         <td id="T_74359_row3_col1" class="data row3 col1" >$3.22</td>
#                         <td id="T_74359_row3_col2" class="data row3 col2" >$28.99</td>
#             </tr>
#             <tr>
#                         <th id="T_74359_level0_row4" class="row_heading level0 row4" >108</th>
#                         <th id="T_74359_level1_row4" class="row_heading level1 row4" >Extraction, Quickblade Of Trembling Hands</th>
#                         <td id="T_74359_row4_col0" class="data row4 col0" >9</td>
#                         <td id="T_74359_row4_col1" class="data row4 col1" >$3.53</td>
#                         <td id="T_74359_row4_col2" class="data row4 col2" >$31.77</td>
#             </tr>
#     </tbody></table>

# %%
most_profitable_items_df = most_popular_items_df.sort_values(by='Total Purchase Value', ascending=False).head()

most_profitable_items_df.style.format({
    "Item Price": "${:.2f}",
    "Total Purchase Value": "${:.2f}"
})
# Out:
# <style  type="text/css" >
# </style><table id="T_d68b6_" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Purchase Count</th>        <th class="col_heading level0 col1" >Item Price</th>        <th class="col_heading level0 col2" >Total Purchase Value</th>    </tr>    <tr>        <th class="index_name level0" >Item ID</th>        <th class="index_name level1" >Item Name</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d68b6_level0_row0" class="row_heading level0 row0" >92</th>
#                         <th id="T_d68b6_level1_row0" class="row_heading level1 row0" >Final Critic</th>
#                         <td id="T_d68b6_row0_col0" class="data row0 col0" >13</td>
#                         <td id="T_d68b6_row0_col1" class="data row0 col1" >$4.61</td>
#                         <td id="T_d68b6_row0_col2" class="data row0 col2" >$59.99</td>
#             </tr>
#             <tr>
#                         <th id="T_d68b6_level0_row1" class="row_heading level0 row1" >178</th>
#                         <th id="T_d68b6_level1_row1" class="row_heading level1 row1" >Oathbreaker, Last Hope of the Breaking Storm</th>
#                         <td id="T_d68b6_row1_col0" class="data row1 col0" >12</td>
#                         <td id="T_d68b6_row1_col1" class="data row1 col1" >$4.23</td>
#                         <td id="T_d68b6_row1_col2" class="data row1 col2" >$50.76</td>
#             </tr>
#             <tr>
#                         <th id="T_d68b6_level0_row2" class="row_heading level0 row2" >82</th>
#                         <th id="T_d68b6_level1_row2" class="row_heading level1 row2" >Nirvana</th>
#                         <td id="T_d68b6_row2_col0" class="data row2 col0" >9</td>
#                         <td id="T_d68b6_row2_col1" class="data row2 col1" >$4.90</td>
#                         <td id="T_d68b6_row2_col2" class="data row2 col2" >$44.10</td>
#             </tr>
#             <tr>
#                         <th id="T_d68b6_level0_row3" class="row_heading level0 row3" >145</th>
#                         <th id="T_d68b6_level1_row3" class="row_heading level1 row3" >Fiery Glass Crusader</th>
#                         <td id="T_d68b6_row3_col0" class="data row3 col0" >9</td>
#                         <td id="T_d68b6_row3_col1" class="data row3 col1" >$4.58</td>
#                         <td id="T_d68b6_row3_col2" class="data row3 col2" >$41.22</td>
#             </tr>
#             <tr>
#                         <th id="T_d68b6_level0_row4" class="row_heading level0 row4" >103</th>
#                         <th id="T_d68b6_level1_row4" class="row_heading level1 row4" >Singed Scalpel</th>
#                         <td id="T_d68b6_row4_col0" class="data row4 col0" >8</td>
#                         <td id="T_d68b6_row4_col1" class="data row4 col1" >$4.35</td>
#                         <td id="T_d68b6_row4_col2" class="data row4 col2" >$34.80</td>
#             </tr>
#     </tbody></table>
